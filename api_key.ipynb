# %% [markdown]
# <a href="https://colab.research.google.com/github/shriswathi06/linlustro-training-even-semesterr/blob/main/api_key.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.generativeai import GenerativeModel, configure
configure (api_key="AIzaSyDsGPUOlycf_0H8P2AB-g9yBjgIPcXgxRM")
model = GenerativeModel ("gemini-1.5-pro")
print("Welcome to AI chatbot! Type 'exit' to stop.")
while True:
     user_input = input("you:")
     if user_input.lower() == "exit":
        break
     response = model.generate_content(user_input)
     print("AI:", response.text)
# Out:
# Welcome to AI chatbot! Type 'exit' to stop.
# you:Hii
# AI: Hi there! How can I help you today?
#
# you:How are you
# AI: I'm doing well, thank you for asking! How are you today?
#
# you:exit
